# %%
#impot libraries
import numpy as np
import pandas as pd
from requests import get
from time import sleep
from random import randint
from selenium import webdriver
from bs4 import BeautifulSoup
from datetime import datetime
from urllib.request import urlopen
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import seaborn as sns
# %matplotlib inline
import re
import time
import requests

# %%
#Main url containing all books and links to different book categories
books_url = 'https://www.amazon.com/s?i=stripbooks&bbn=283155&rh=n%3A283155&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602339864&unfiltered=1&ref=sr_ex_n_1'

# %%
#Get the link for each of allcategories
driver = webdriver.Chrome("chromedriver.exe")
driver.get(books_url)
sleep(randint(5,15))
soup = BeautifulSoup(driver.page_source, 'html.parser')
category_urls = [item.get("href") for item in soup.find_all("a")]

#Remove duplicates and none values
urls = list(dict.fromkeys(category_urls))
urls = list(filter(None, urls))

# %%
#Get all the links that starts with '/s?i=stripbooks'
urls = [x for x in urls if x.startswith('/s?i=stripbooks')]

#Remove all links that ends with ''browse-bin_1''
urls = [x for x in urls if not x.endswith('browse-bin_1')]
#prefixes =  ('sr_pg_1', 'sr_pg_2','sr_pg_3')
   # url_final = [x for x in url_final if x.endswith(prefixes)]

#to make sure the links mirrors the original link, we need to add the main to amazon website to all sublinks gotten from the html source code 
string = 'https://www.amazon.com/'
final_list=[string + s for s in urls]

# %%
final_list
# Out:
# ['https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A1&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_1',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A2&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_2',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A3&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_3',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A3248857011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_4',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A4&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_5',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A12290&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_6',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A4366&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_7',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A5&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_8',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A6&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_9',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A48&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_10',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A8975347011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_11',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A173507&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_12',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A10&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_13',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A9&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_14',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A86&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_15',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A10777&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_16',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A301889&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_17',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A17&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_18',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A173514&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_19',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A18&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_20',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A20&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_21',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A3377866011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_22',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A21&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_23',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A22&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_24',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A23&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_25',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A75&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_26',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A25&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_27',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A4736&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_28',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A26&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_29',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A28&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_30',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A5267710011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_31',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A27&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_32',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_72%3A1250221011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1250219011&unfiltered=1&ref=sr_nr_p_72_1',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_72%3A1250222011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1250219011&unfiltered=1&ref=sr_nr_p_72_2',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_72%3A1250223011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1250219011&unfiltered=1&ref=sr_nr_p_72_3',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_72%3A1250224011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1250219011&unfiltered=1&ref=sr_nr_p_72_4',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_lbr_books_series_browse-bin%3ADog+Man&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=3275128011&unfiltered=1&ref=sr_nr_p_lbr_books_series_browse-bin_2',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_lbr_books_series_browse-bin%3APicture+Puffins&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=3275128011&unfiltered=1&ref=sr_nr_p_lbr_books_series_browse-bin_3',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_lbr_books_series_browse-bin%3ATrials+of+Apollo&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=3275128011&unfiltered=1&ref=sr_nr_p_lbr_books_series_browse-bin_4',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_lbr_books_series_browse-bin%3AA+Mitch+Rapp+Novel&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=3275128011&unfiltered=1&ref=sr_nr_p_lbr_books_series_browse-bin_5',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_lbr_books_series_browse-bin%3AToltec+Wisdom&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=3275128011&unfiltered=1&ref=sr_nr_p_lbr_books_series_browse-bin_6',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_lbr_books_series_browse-bin%3ADumpty&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=3275128011&unfiltered=1&ref=sr_nr_p_lbr_books_series_browse-bin_7',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_n_publication_date%3A1250226011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1250225011&unfiltered=1&ref=sr_nr_p_n_publication_date_1',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155%2Cp_n_publication_date%3A1250227011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1

#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155&s=review-count-rank&dc&page=2&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&unfiltered=1&ref=sr_pg_2',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155&s=review-count-rank&dc&page=3&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&unfiltered=1&ref=sr_pg_3',
#  'https://www.amazon.com//s?i=stripbooks&bbn=283155&rh=n%3A283155&s=review-count-rank&dc&page=2&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&unfiltered=1&ref=sr_pg_1']

# %%
#the frist 32 links are the links to recorn with. 
final_urls =final_list[:32]
final_urls
# Out:
# ['https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A1&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_1',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A2&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_2',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A3&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_3',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A3248857011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_4',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A4&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_5',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A12290&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_6',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A4366&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_7',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A5&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_8',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A6&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_9',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A48&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_10',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A8975347011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_11',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A173507&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_12',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A10&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_13',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A9&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_14',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A86&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_15',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A10777&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_16',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A301889&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_17',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A17&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_18',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A173514&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_19',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A18&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_20',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A20&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_21',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A3377866011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_22',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A21&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_23',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A22&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_24',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A23&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_25',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A75&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_26',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A25&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_27',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A4736&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_28',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A26&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_29',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A28&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_30',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A5267710011&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_31',
#  'https://www.amazon.com//s?i=stripbooks&bbn=1000&rh=n%3A283155%2Cn%3A27&s=review-count-rank&dc&Adv-Srch-Books-Submit.x=30&Adv-Srch-Books-Submit.y=21&qid=1602618511&rnid=1000&unfiltered=1&ref=sr_nr_n_32']

# %%
page_list = []
for url in final_urls:
    driver = webdriver.Chrome("chromedriver.exe")
    driver.get(url)  
    sleep(randint(5,15))
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    page_urls = [item.get("href") for item in soup.find_all("a")]

#Remove duplicates and none values
    urls_final = list(dict.fromkeys(page_urls))
    urls_final = list(filter(None, urls_final)) 


#Get all the links that starts with '/s?i=stripbooks'
    url_final = [x for x in urls_final if x.startswith('/s?i=stripbooks')]
#Remove all links that ends with ''h_1''
    url_final = [x for x in url_final if not x.endswith('hi_1')]
    
#the links we need all end with either of the strings in 'prefixes' below
    prefixes =  ('sr_pg_1', 'sr_pg_2','sr_pg_3')
    url_final = [x for x in url_final if x.endswith(prefixes)]

#to make sure the links mirrors the original link, we need to add the main link to amazon to all sublinks gotten from the html source code    
    string = 'https://www.amazon.com/'
    final_list=[string + s for s in url_final]
    final_pages =final_list[0:3]
    page_list.append(final_pages)

# %%
#the links returned from above is a list of list. Let's convert them to a flat list.
flat_list = []
for sublist in page_list:
    for item in sublist:
        flat_list.append(item)

# %%
#Empty list to store the data we will get from the links
title = []
author = []
date = []
stars = []
rating = []
price = []
category = []

# %%
# Iterate through the links in flat_list and collect the wanted data.
for links in flat_list:
        driver = webdriver.Chrome("chromedriver.exe")
        driver.get(links)  
        sleep(randint(2,10))
        from bs4 import BeautifulSoup
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        containers = soup.find_all("div", class_ = "sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-28-of-32 sg-col-16-of-20 sg-col sg-col-32-of-36 sg-col-12-of-16 sg-col-24-of-28")
        for container in containers:
            try:
                title1 = container.find("span", class_="a-size-medium a-color-base a-text-normal").text
                title.append(title1)

                if container.find("div", class_="a-row a-size-base a-color-secondary").find("a", "a-size-base a-link-normal") is None:
                    author.append(container.find("div", class_="a-row a-size-base a-color-secondary").find_all("span", class_="a-size-base")[2].text)
                elif container.find("div", class_="a-row a-size-base a-color-secondary").find("a", "a-size-base a-link-normal") is not None:
                    author1 = container.find("div", class_="a-row a-size-base a-color-secondary").find("a", "a-size-base a-link-normal").text.strip()
                    author.append(author1)
                else: author.append("-")
            except IndexError:
                author.append('No Author')
                
             
            if container.find("span", "a-size-base a-color-secondary a-text-normal") is not None:
                date1 = container.find("span", "a-size-base a-color-secondary a-text-normal").text
                date.append(date1)
            else: date.append("-")

            if container.find("i", "a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom") is not None:
                star1 = float(container.find("i", "a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom").text.replace(" out of 5 stars",""))
                stars.append(star1)
            else: stars.append("-")

            if container.find("div", class_="a-row a-size-small") is not None:
                rating1 = int(container.find("div", class_="a-row a-size-small").find("span", class_="a-size-base").text.replace(",",""))
                rating.append(rating1)
            else: rating.append("-")
            
            
            cat = soup.find_all('span', class_="a-size-base a-color-base a-text-bold")[2].text
            category.append(cat)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-10-6278436d6085> in <module>
#       2 for links in flat_list:
#       3         driver = webdriver.Chrome("chromedriver.exe")
# ----> 4         driver.get(links)
#       5         sleep(randint(2,10))
#       6         from bs4 import BeautifulSoup
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 288.027
#   (Session info: chrome=85.0.4183.121)

# %%
#Combine the lists into a dataframe
books = pd.DataFrame({"TITLE":title, "AUTHOR":author, "DATE":date,'STAR':stars , "RATING":rating, "CATEGORY":category})

# %%
books
# Out:
#                                                  TITLE            AUTHOR  \
# 0    Alice's Adventures in Wonderland: 150th Annive...     Lewis Carroll
# 1    First Little Readers Parent Pack: Guided Readi...  Deborah Schecter
# 2    Lettering and Modern Calligraphy: A Beginner's...                |
# 3    Disney Dreams Collection Thomas Kinkade Studio...    Thomas Kinkade
# 4    Hinch Yourself Happy: All The Best Cleaning Ti...         Mrs Hinch
# ..                                                 ...               ...
# 219                          Where the Wild Things Are    Maurice Sendak
# 220                A Christmas Carol (Bantam Classics)   Charles Dickens
# 221  I Am Confident, Brave & Beautiful: A Coloring ...   Hopscotch Girls
# 222  Percy Jackson and the Olympians 5 Book Paperba...      Rick Riordan
# 223  The Pout-Pout Fish (A Pout-Pout Fish Adventure...    Deborah Diesen
#
#              DATE STAR  RATING            CATEGORY
# 0    Sep 29, 2015  4.5    8259  Arts & Photography
# 1     Oct 1, 2010  4.7    8170  Arts & Photography
# 2    Oct 27, 2017  4.4    8156  Arts & Photography
# 3    Sep 19, 2017  4.7    8004  Arts & Photography
# 4     Apr 4, 2019  4.7    7739  Arts & Photography
# ..            ...  ...     ...                 ...
# 219  Dec 26, 2012    -   10980    Children's Books
# 220   Nov 1, 1986  4.6   10705    Children's Books
# 221  Nov 13, 2017    -   10614    Children's Books
# 222   Jun 3, 2014    -   10580    Children's Books
# 223  Mar 18, 2008    -   10534    Children's Books
#
# [224 rows x 6 columns]

# %%
# converting the data to a csv file to use for analysis
books.to_csv("Amazon Books.csv")
